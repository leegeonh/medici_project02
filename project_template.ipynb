# %% [markdown]
# # [MLB 데이터베이스]

# %% [markdown]
# *   기간: 2023-05-12 ~ yyyy-mm-dd (총 n일)
# *   리더: 이건희
# *   정의: mlb 데이터 분석
# *   목적:
# *   범위: 2013 - 현재까지의 mlb 팀, 선수, 게임, 코치의 데이터

# %% [markdown]
# ## [할 일 목록]

# %% [markdown]
# ## [이슈 항목]
